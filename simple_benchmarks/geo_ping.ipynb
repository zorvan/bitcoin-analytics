# %%
import pandas as pd

dic = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQetgcDXPtX0-bD333HqUKbS-k66-eGh5yTHmTT85N59uPA6ozpHQnKczrmxR3d-7UOJ6v2EoukCn9o/pub?gid=735639585&single=true&output=csv"
services = pd.read_csv(dic)

print (len(services))
# Out:
# 229

# %%
import requests
import json
import time

def getcountry(ip):
    KEY = "e52ea3af34144855795d5e70b61ed107064383152ee97feed21d46a1d646180e"
    url = "http://api.ipinfodb.com/v3/ip-city/?key="+KEY+"&ip="+ip
#     url = "http://api.ipinfodb.com/v3/ip-country/?key="+KEY+"&ip="+ip
    country_result = requests.get(url)
    time.sleep(0.5)
#     return country_result.text.split(";")[4] + "("+country_result.text.split(";")[3]+")"
    return country_result.text.split(";")

address = getcountry("occc.ir")
print(address)
# Out:
# ['OK', '', '185.4.29.100', 'IR', 'Iran, Islamic Republic of', 'Esfahan', 'Esfahan', '81464', '32.6572', '51.6776', '+04:30']

# %%
import requests
import json
import pprint as pp

url2= "http://myos.ir:8081/catalog/servers"
headers2 = {'IDENTITY_KEY': '46bf4060d758ba03488ca76947d317575f6872732e398c9db72707e25c7e0756'}

for index, value in services.iterrows():
    address = getcountry(value["Address"])

    data = {"sensors":[
    {"sensor": value["Address"].replace(".","_"),
    "description":"cloud service",
    #"type":"air_quality_pm25", 
    "type":"generic", 
#     "dataType":"number",
#     "unit":"",
    "component": value["Address"].replace(".","_").replace("/",""), 
    "componentType":"generic",
    "componentDesc":"cloud service",
    "publicAccess" : True,
    "location":"{} {}".format(address[8],address[9]),
    "timeZone":"CET" }]}
    data_json = json.dumps(data)
    pp.pprint (data_json)

    response = requests.post(url2, data=data_json, headers=headers2)
    print(response.status_code,response.content)
# Out:
# ('{"sensors": [{"sensor": "taskulu_com", "description": "cloud service", '
#  '"type": "generic", "component": "taskulu_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "peygir_net", "description": "cloud service", '
#  '"type": "generic", "component": "peygir_net", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "elenoon_ir", "description": "cloud service", '
#  '"type": "generic", "component": "elenoon_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "chmail_ir", "description": "cloud service", "type": '
#  '"generic", "component": "chmail_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "evand_ir", "description": "cloud service", "type": '
#  '"generic", "component": "evand_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.1155 '
#  '8.68417", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "e-seminar_ir", "description": "cloud service", '
#  '"type": "generic", "component": "e-seminar_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "37.2808 '
#  '49.5832", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "shooka_ir", "description": "cloud service", "type": '
#  '"generic", "component": "shooka_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "lahzenegar_com", "description": "cloud service", '
#  '"type": "generic", "component": "lahzenegar_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "41.6139 -72.7725", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "bayanbox_ir", "description": "cloud service", '
#  '"type": "generic", "component": "bayanbox_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521981174681"}'
# ('{"sensors": [{"sensor": "trainbit_com", "description": "cloud service", '
#  '"type": "generic", "component": "trainbit_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "zamanak_ir", "description": "cloud service", '
#  '"type": "generic", "component": "zamanak_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "fax_ir", "description": "cloud service", "type": '
#  '"generic", "component": "fax_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sms-bazar_ir", "description": "cloud service", '
#  '"type": "generic", "component": "sms-bazar_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "36.297 '
#  '59.6062", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sms_ghasedak-ict_com", "description": "cloud '
#  'service", "type": "generic", "component": "sms_ghasedak-ict_com", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "aparat_com", "description": "cloud service", '
#  '"type": "generic", "component": "aparat_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abresalamat_ir", "description": "cloud service", '
#  '"type": "generic", "component": "abresalamat_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "targoman_ir", "description": "cloud service", '
#  '"type": "generic", "component": "targoman_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parstranslator_net", "description": "cloud '
#  'service", "type": "generic", "component": "parstranslator_net", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "43.7195 -79.3319", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "translate_parsijoo_ir", "description": "cloud '
#  'service", "type": "generic", "component": "translate_parsijoo_ir", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "razipoornet_ir", "description": "cloud service", '
#  '"type": "generic", "component": "razipoornet_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "serverping_ir", "description": "cloud service", '
#  '"type": "generic", "component": "serverping_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "bisphone_com", "description": "cloud service", '
#  '"type": "generic", "component": "bisphone_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "salamup_ir", "description": "cloud service", '
#  '"type": "generic", "component": "salamup_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "syna-app_ir", "description": "cloud service", '
#  '"type": "generic", "component": "syna-app_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "map_elenoon_ir", "description": "cloud service", '
#  '"type": "generic", "component": "map_elenoon_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "map_parsijoo_ir", "description": "cloud service", '
#  '"type": "generic", "component": "map_parsijoo_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "map_tehran_ir", "description": "cloud service", '
#  '"type": "generic", "component": "map_tehran_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "maktabkhooneh_org", "description": "cloud service", '
#  '"type": "generic", "component": "maktabkhooneh_org", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "50.9333 6.95", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "takhtesefid_org", "description": "cloud service", '
#  '"type": "generic", "component": "takhtesefid_org", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "50.9333 6.95", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "kelasedars_org", "description": "cloud service", '
#  '"type": "generic", "component": "kelasedars_org", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "37.3394 -121.895", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "webyad_com", "description": "cloud service", '
#  '"type": "generic", "component": "webyad_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "iranlms_ir", "description": "cloud service", '
#  '"type": "generic", "component": "iranlms_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abreamoozesh_ir", "description": "cloud service", '
#  '"type": "generic", "component": "abreamoozesh_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "darsname_com", "description": "cloud service", '
#  '"type": "generic", "component": "darsname_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "tikkhan_com", "description": "cloud service", '
#  '"type": "generic", "component": "tikkhan_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "irvex_ir", "description": "cloud service", "type": '
#  '"generic", "component": "irvex_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "yadamooz_ir", "description": "cloud service", '
#  '"type": "generic", "component": "yadamooz_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "nikteacher_com", "description": "cloud service", '
#  '"type": "generic", "component": "nikteacher_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "0 0", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parsijoo_ir", "description": "cloud service", '
#  '"type": "generic", "component": "parsijoo_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "yooz_ir", "description": "cloud service", "type": '
#  '"generic", "component": "yooz_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "jasjoo_com", "description": "cloud service", '
#  '"type": "generic", "component": "jasjoo_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "rismoon_com", "description": "cloud service", '
#  '"type": "generic", "component": "rismoon_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "30.3241 '
#  '-81.6809", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "salam_ir", "description": "cloud service", "type": '
#  '"generic", "component": "salam_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parseek", "description": "cloud service", "type": '
#  '"generic", "component": "parseek", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "payab_com", "description": "cloud service", "type": '
#  '"generic", "component": "payab_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "59.3793 '
#  '13.5036", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "torob_ir", "description": "cloud service", "type": '
#  '"generic", "component": "torob_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "51.5085 '
#  '-0.12574", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "nebeek_com", "description": "cloud service", '
#  '"type": "generic", "component": "nebeek_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "jeeb_ir", "description": "cloud service", "type": '
#  '"generic", "component": "jeeb_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "36.297 '
#  '59.6062", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hesabak_com", "description": "cloud service", '
#  '"type": "generic", "component": "hesabak_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "costsbook_com", "description": "cloud service", '
#  '"type": "generic", "component": "costsbook_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521981553874"}'
# ('{"sensors": [{"sensor": "kharjobarj_ir", "description": "cloud service", '
#  '"type": "generic", "component": "kharjobarj_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hesabdan_com", "description": "cloud service", '
#  '"type": "generic", "component": "hesabdan_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "31.8972 '
#  '54.3675", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "takzarb", "description": "cloud service", "type": '
#  '"generic", "component": "takzarb", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "rayanroyal_com", "description": "cloud service", '
#  '"type": "generic", "component": "rayanroyal_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "0 0", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "rozaneco_com", "description": "cloud service", '
#  '"type": "generic", "component": "rozaneco_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "my_bmi_ir", "description": "cloud service", "type": '
#  '"generic", "component": "my_bmi_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "phpc_ir", "description": "cloud service", "type": '
#  '"generic", "component": "phpc_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "39.0437 '
#  '-77.4875", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hpcrc_aut_ac_ir", "description": "cloud service", '
#  '"type": "generic", "component": "hpcrc_aut_ac_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "me_ut_ac_ir", "description": "cloud service", '
#  '"type": "generic", "component": "me_ut_ac_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE99-1521981589174"}'
# ('{"sensors": [{"sensor": "arvancloud_com", "description": "cloud service", '
#  '"type": "generic", "component": "arvancloud_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "41.6139 -72.7725", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cdn_persiangig_com", "description": "cloud '
#  'service", "type": "generic", "component": "cdn_persiangig_com", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "41.8782 -87.6254", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "asiatech_ir", "description": "cloud service", '
#  '"type": "generic", "component": "asiatech_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "iranserver_com", "description": "cloud service", '
#  '"type": "generic", "component": "iranserver_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "33.4484 -112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sainacloud_ir", "description": "cloud service", '
#  '"type": "generic", "component": "sainacloud_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ethost_ir", "description": "cloud service", "type": '
#  '"generic", "component": "ethost_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.374 '
#  '4.88969", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "afranet_com", "description": "cloud service", '
#  '"type": "generic", "component": "afranet_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "persiangig_com", "description": "cloud service", '
#  '"type": "generic", "component": "persiangig_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "41.8782 -87.6254", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "vpsfa_com", "description": "cloud service", "type": '
#  '"generic", "component": "vpsfa_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parspack_com", "description": "cloud service", '
#  '"type": "generic", "component": "parspack_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "fanavaidc_com", "description": "cloud service", '
#  '"type": "generic", "component": "fanavaidc_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "XaaS_ir", "description": "cloud service", "type": '
#  '"generic", "component": "XaaS_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "tebyancloud_ir", "description": "cloud service", '
#  '"type": "generic", "component": "tebyancloud_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "pardisco_ir", "description": "cloud service", '
#  '"type": "generic", "component": "pardisco_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "innfinision_net", "description": "cloud service", '
#  '"type": "generic", "component": "innfinision_net", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "mojnovin_com", "description": "cloud service", '
#  '"type": "generic", "component": "mojnovin_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "51.2468 '
#  '0.60682", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "pdnsoft_com", "description": "cloud service", '
#  '"type": "generic", "component": "pdnsoft_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.5244 '
#  '13.4105", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abarsoft_ir", "description": "cloud service", '
#  '"type": "generic", "component": "abarsoft_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "28.9684 '
#  '50.8385", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "crc_aut_ac_ir", "description": "cloud service", '
#  '"type": "generic", "component": "crc_aut_ac_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "nhpcc_iut_ac_ir", "description": "cloud service", '
#  '"type": "generic", "component": "nhpcc_iut_ac_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "32.6572 51.6776", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hpclab_ir", "description": "cloud service", "type": '
#  '"generic", "component": "hpclab_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "datapool_ir", "description": "cloud service", '
#  '"type": "generic", "component": "datapool_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "49.4478 '
#  '11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "air_tehran_ir", "description": "cloud service", '
#  '"type": "generic", "component": "air_tehran_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "trafficcontrol_tehran_ir", "description": "cloud '
#  'service", "type": "generic", "component": "trafficcontrol_tehran_ir", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cafepardazesh_com", "description": "cloud service", '
#  '"type": "generic", "component": "cafepardazesh_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "32.6572 51.6776", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "opengit_ir", "description": "cloud service", '
#  '"type": "generic", "component": "opengit_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "32.6572 '
#  '51.6776", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sepehrcc_com", "description": "cloud service", '
#  '"type": "generic", "component": "sepehrcc_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "blogfa_com", "description": "cloud service", '
#  '"type": "generic", "component": "blogfa_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "blog_ir", "description": "cloud service", "type": '
#  '"generic", "component": "blog_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "mihanblog_com", "description": "cloud service", '
#  '"type": "generic", "component": "mihanblog_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "blogers_ir", "description": "cloud service", '
#  '"type": "generic", "component": "blogers_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "persianblog_ir", "description": "cloud service", '
#  '"type": "generic", "component": "persianblog_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "chikablog_ir", "description": "cloud service", '
#  '"type": "generic", "component": "chikablog_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "backtory_com", "description": "cloud service", '
#  '"type": "generic", "component": "backtory_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "pushe_co", "description": "cloud service", "type": '
#  '"generic", "component": "pushe_co", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521981829930"}'
# ('{"sensors": [{"sensor": "form_ghasedak-ict_com", "description": "cloud '
#  'service", "type": "generic", "component": "form_ghasedak-ict_com", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "porseshnameonline_com", "description": "cloud '
#  'service", "type": "generic", "component": "porseshnameonline_com", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "snapp_ir", "description": "cloud service", "type": '
#  '"generic", "component": "snapp_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521981915997"}'
# ('{"sensors": [{"sensor": "tap30_ir", "description": "cloud service", "type": '
#  '"generic", "component": "tap30_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.1155 '
#  '8.68417", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ponisha_ir", "description": "cloud service", '
#  '"type": "generic", "component": "ponisha_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.1155 '
#  '8.68417", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "divar_ir", "description": "cloud service", "type": '
#  '"generic", "component": "divar_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sheypoor_com", "description": "cloud service", '
#  '"type": "generic", "component": "sheypoor_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hadoop_ir", "description": "cloud service", "type": '
#  '"generic", "component": "hadoop_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "37.2808 '
#  '49.5832", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "wilens_ir", "description": "cloud service", "type": '
#  '"generic", "component": "wilens_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "gugana_ir", "description": "cloud service", "type": '
#  '"generic", "component": "gugana_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "34.6401 '
#  '50.8764", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abrino_ir", "description": "cloud service", "type": '
#  '"generic", "component": "abrino_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "poshtiban_com", "description": "cloud service", '
#  '"type": "generic", "component": "poshtiban_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "49.4478 '
#  '11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "filecorn_com", "description": "cloud service", '
#  '"type": "generic", "component": "filecorn_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "nazarbazaar_ir", "description": "cloud service", '
#  '"type": "generic", "component": "nazarbazaar_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "50.1155 8.68417", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "telobal_com", "description": "cloud service", '
#  '"type": "generic", "component": "telobal_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.7536 '
#  '-84.3901", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "autosaze_com", "description": "cloud service", '
#  '"type": "generic", "component": "autosaze_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "weclick_ir", "description": "cloud service", '
#  '"type": "generic", "component": "weclick_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "49.4478 '
#  '11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ikhedmat_com", "description": "cloud service", '
#  '"type": "generic", "component": "ikhedmat_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "36.297 '
#  '59.6062", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "webide_ir", "description": "cloud service", "type": '
#  '"generic", "component": "webide_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "urmiahost_com", "description": "cloud service", '
#  '"type": "generic", "component": "urmiahost_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521982172626"}'
# ('{"sensors": [{"sensor": "hostnegar_com", "description": "cloud service", '
#  '"type": "generic", "component": "hostnegar_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521982234237"}'
# ('{"sensors": [{"sensor": "netservice_ir", "description": "cloud service", '
#  '"type": "generic", "component": "netservice_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.5244 '
#  '13.4105", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521982295939"}'
# ('{"sensors": [{"sensor": "nahrup_ir", "description": "cloud service", "type": '
#  '"generic", "component": "nahrup_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "48.3233 '
#  '11.6012", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521982357868"}'
# ('{"sensors": [{"sensor": "tarino_ir", "description": "cloud service", "type": '
#  '"generic", "component": "tarino_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "31.1608 '
#  '52.6506", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE00-1521982419706"}'
# ('{"sensors": [{"sensor": "recommender_ir", "description": "cloud service", '
#  '"type": "generic", "component": "recommender_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "venutel_com", "description": "cloud service", '
#  '"type": "generic", "component": "venutel_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "negarbot_ir", "description": "cloud service", '
#  '"type": "generic", "component": "negarbot_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "anbardari_ir", "description": "cloud service", '
#  '"type": "generic", "component": "anbardari_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "48.3233 '
#  '11.6012", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cavan_ir", "description": "cloud service", "type": '
#  '"generic", "component": "cavan_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.374 '
#  '4.88969", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hostplus_ir/", "description": "cloud service", '
#  '"type": "generic", "component": "hostplus_ir/", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 400 b'{"code":400,"message":"Bad request data. Sensors have not been inserted. Please review the following errors","errorDetails":["Sensor hostplus_ir/ has fields not filled in correctly. Please make sure following fields are filled in properly: [sensor]","Component hostplus_ir/ has fields not filled in correctly. Please make sure following fields are filled in properly: [name]"]}'
# ('{"sensors": [{"sensor": "ekbatanhost_ir", "description": "cloud service", '
#  '"type": "generic", "component": "ekbatanhost_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "49.4478 11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hamiweb_com", "description": "cloud service", '
#  '"type": "generic", "component": "hamiweb_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "45.3168 '
#  '-73.8659", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "www_chichosting_net", "description": "cloud '
#  'service", "type": "generic", "component": "www_chichosting_net", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ziping_ir", "description": "cloud service", "type": '
#  '"generic", "component": "ziping_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cheshmak_me", "description": "cloud service", '
#  '"type": "generic", "component": "cheshmak_me", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "49.4478 '
#  '11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abrin_ir", "description": "cloud service", "type": '
#  '"generic", "component": "abrin_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.7951 '
#  '-1.12902", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ugig_in", "description": "cloud service", "type": '
#  '"generic", "component": "ugig_in", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hamisun_ir", "description": "cloud service", '
#  '"type": "generic", "component": "hamisun_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "keloud_ir", "description": "cloud service", "type": '
#  '"generic", "component": "keloud_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "chapiroos_com", "description": "cloud service", '
#  '"type": "generic", "component": "chapiroos_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abarcloud_ir", "description": "cloud service", '
#  '"type": "generic", "component": "abarcloud_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.374 '
#  '4.88969", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hkpos_ir", "description": "cloud service", "type": '
#  '"generic", "component": "hkpos_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "45.5088 '
#  '-73.5878", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hrcloud_ir", "description": "cloud service", '
#  '"type": "generic", "component": "hrcloud_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "pendarideas_com", "description": "cloud service", '
#  '"type": "generic", "component": "pendarideas_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "49.4478 11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "malek-co_com", "description": "cloud service", '
#  '"type": "generic", "component": "malek-co_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "37.2808 '
#  '49.5832", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "commentminer_com", "description": "cloud service", '
#  '"type": "generic", "component": "commentminer_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cedarmaps_com", "description": "cloud service", '
#  '"type": "generic", "component": "cedarmaps_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "www_pcloud_com", "description": "cloud service", '
#  '"type": "generic", "component": "www_pcloud_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "26.1211 -80.1292", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": '
#  '"eportal_tci_ir/%D8%AF%D9%81%D8%AA%D8%B1%DA%A9%D8%A7%D8%B1-%D8%A7%D8%A8%D8%B1%DB%8C", '
#  '"description": "cloud service", "type": "generic", "component": '
#  '"eportal_tci_ir/%D8%AF%D9%81%D8%AA%D8%B1%DA%A9%D8%A7%D8%B1-%D8%A7%D8%A8%D8%B1%DB%8C", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "0 0", "timeZone": "CET"}]}')
# 400 b'{"code":400,"message":"Bad request data. Sensors have not been inserted. Please review the following errors","errorDetails":["Sensor eportal_tci_ir/%D8%AF%D9%81%D8%AA%D8%B1%DA%A9%D8%A7%D8%B1-%D8%A7%D8%A8%D8%B1%DB%8C has fields not filled in correctly. Please make sure following fields are filled in properly: [sensor]","Component eportal_tci_ir/%D8%AF%D9%81%D8%AA%D8%B1%DA%A9%D8%A7%D8%B1-%D8%A7%D8%A8%D8%B1%DB%8C has fields not filled in correctly. Please make sure following fields are filled in properly: [name]"]}'
# ('{"sensors": [{"sensor": "MiCloud_ir", "description": "cloud service", '
#  '"type": "generic", "component": "MiCloud_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ehost_ir", "description": "cloud service", "type": '
#  '"generic", "component": "ehost_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "drdr_ir", "description": "cloud service", "type": '
#  '"generic", "component": "drdr_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "41.6139 '
#  '-72.7725", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "miztahrir_ir", "description": "cloud service", '
#  '"type": "generic", "component": "miztahrir_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "www_pouyasazan_org", "description": "cloud '
#  'service", "type": "generic", "component": "www_pouyasazan_org", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "42.7333 -84.6378", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "adsensor_ir", "description": "cloud service", '
#  '"type": "generic", "component": "adsensor_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abrestan_com", "description": "cloud service", '
#  '"type": "generic", "component": "abrestan_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "48.3233 '
#  '11.6012", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cloudino_ir", "description": "cloud service", '
#  '"type": "generic", "component": "cloudino_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "37.7749 '
#  '-122.419", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "deskbit_io", "description": "cloud service", '
#  '"type": "generic", "component": "deskbit_io", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "40.7347 '
#  '-74.0059", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "alohi_com", "description": "cloud service", "type": '
#  '"generic", "component": "alohi_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "virastlive_com", "description": "cloud service", '
#  '"type": "generic", "component": "virastlive_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "39.1478 -94.5689", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "jibital_ir", "description": "cloud service", '
#  '"type": "generic", "component": "jibital_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "48.3233 '
#  '11.6012", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "teamcamp_me", "description": "cloud service", '
#  '"type": "generic", "component": "teamcamp_me", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "iran_ir", "description": "cloud service", "type": '
#  '"generic", "component": "iran_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "32.6572 '
#  '51.6776", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "gap_im/", "description": "cloud service", "type": '
#  '"generic", "component": "gap_im/", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 400 b'{"code":400,"message":"Bad request data. Sensors have not been inserted. Please review the following errors","errorDetails":["Sensor gap_im/ has fields not filled in correctly. Please make sure following fields are filled in properly: [sensor]","Component gap_im/ has fields not filled in correctly. Please make sure following fields are filled in properly: [name]"]}'
# ('{"sensors": [{"sensor": "soroush-app_ir", "description": "cloud service", '
#  '"type": "generic", "component": "soroush-app_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "paziresh24_com", "description": "cloud service", '
#  '"type": "generic", "component": "paziresh24_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "porsline_ir", "description": "cloud service", '
#  '"type": "generic", "component": "porsline_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "zdesk_ir", "description": "cloud service", "type": '
#  '"generic", "component": "zdesk_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "smdata_ir", "description": "cloud service", "type": '
#  '"generic", "component": "smdata_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "kurdcloud_ir", "description": "cloud service", '
#  '"type": "generic", "component": "kurdcloud_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hostiran_net", "description": "cloud service", '
#  '"type": "generic", "component": "hostiran_net", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "Niniweblog_com", "description": "cloud service", '
#  '"type": "generic", "component": "Niniweblog_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "Professora_ir", "description": "cloud service", '
#  '"type": "generic", "component": "Professora_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "49.4478 '
#  '11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "Blogparsi_com", "description": "cloud service", '
#  '"type": "generic", "component": "Blogparsi_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.5244 '
#  '13.4105", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "Titrblog_ir", "description": "cloud service", '
#  '"type": "generic", "component": "Titrblog_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "51.9592 '
#  '4.21389", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "favapars_ir/guest/files/Appy-fa_pdf", '
#  '"description": "cloud service", "type": "generic", "component": '
#  '"favapars_ir/guest/files/Appy-fa_pdf", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 400 b'{"code":400,"message":"Bad request data. Sensors have not been inserted. Please review the following errors","errorDetails":["Sensor favapars_ir/guest/files/Appy-fa_pdf has fields not filled in correctly. Please make sure following fields are filled in properly: [sensor]","Component favapars_ir/guest/files/Appy-fa_pdf has fields not filled in correctly. Please make sure following fields are filled in properly: [name]"]}'
# ('{"sensors": [{"sensor": "quantcan_ir", "description": "cloud service", '
#  '"type": "generic", "component": "quantcan_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "48.1374 '
#  '11.5755", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ttbz_ir", "description": "cloud service", "type": '
#  '"generic", "component": "ttbz_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "0 0", '
#  '"timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sourcegit_com", "description": "cloud service", '
#  '"type": "generic", "component": "sourcegit_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.374 '
#  '4.88969", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parsaspace_com", "description": "cloud service", '
#  '"type": "generic", "component": "parsaspace_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 401 b'{"code":401,"message":"Invalid credential 46bf4060d758ba03488ca76947d317575f6872732e398c9db72707e25c7e0756"}'
# ('{"sensors": [{"sensor": "novinhost_org", "description": "cloud service", '
#  '"type": "generic", "component": "novinhost_org", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 401 b'{"code":401,"message":"Invalid credential 46bf4060d758ba03488ca76947d317575f6872732e398c9db72707e25c7e0756"}'
# ('{"sensors": [{"sensor": "nivad_io", "description": "cloud service", "type": '
#  '"generic", "component": "nivad_io", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "33.4484 '
#  '-112.074", "timeZone": "CET"}]}')
# 500 b'{"code":500,"message":"Something went wrong. Please try again. If the problem persists, contact your support site and provide the following error code: SIE99-1521982741428"}'
# ('{"sensors": [{"sensor": "azmoon360_com", "description": "cloud service", '
#  '"type": "generic", "component": "azmoon360_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cloudware_ir", "description": "cloud service", '
#  '"type": "generic", "component": "cloudware_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hpc_shahroodut_ac_ir", "description": "cloud '
#  'service", "type": "generic", "component": "hpc_shahroodut_ac_ir", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "51.5085 -0.12574", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "apadana-platform_ir", "description": "cloud '
#  'service", "type": "generic", "component": "apadana-platform_ir", '
#  '"componentType": "generic", "componentDesc": "cloud service", '
#  '"publicAccess": true, "location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parsdev_ir", "description": "cloud service", '
#  '"type": "generic", "component": "parsdev_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "42.8865 '
#  '-78.8784", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "abarcloud_com", "description": "cloud service", '
#  '"type": "generic", "component": "abarcloud_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "30.2936 '
#  '120.161", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "surin_ir", "description": "cloud service", "type": '
#  '"generic", "component": "surin_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "49.4478 '
#  '11.0683", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "padvish_com", "description": "cloud service", '
#  '"type": "generic", "component": "padvish_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "systemgroup_net", "description": "cloud service", '
#  '"type": "generic", "component": "systemgroup_net", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "pbxcallreport_ir", "description": "cloud service", '
#  '"type": "generic", "component": "pbxcallreport_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "39.0437 -77.4875", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "pcloud_com/fa/", "description": "cloud service", '
#  '"type": "generic", "component": "pcloud_com/fa/", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "0 0", "timeZone": "CET"}]}')
# 400 b'{"code":400,"message":"Bad request data. Sensors have not been inserted. Please review the following errors","errorDetails":["Sensor pcloud_com/fa/ has fields not filled in correctly. Please make sure following fields are filled in properly: [sensor]","Component pcloud_com/fa/ has fields not filled in correctly. Please make sure following fields are filled in properly: [name]"]}'
# ('{"sensors": [{"sensor": "synca_ir", "description": "cloud service", "type": '
#  '"generic", "component": "synca_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "copio_ir", "description": "cloud service", "type": '
#  '"generic", "component": "copio_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "peygir_com", "description": "cloud service", '
#  '"type": "generic", "component": "peygir_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "alounak_com", "description": "cloud service", '
#  '"type": "generic", "component": "alounak_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "kara2000_ir", "description": "cloud service", '
#  '"type": "generic", "component": "kara2000_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "ontimeapp_ir", "description": "cloud service", '
#  '"type": "generic", "component": "ontimeapp_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "52.5244 '
#  '13.4105", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "drdr_ir", "description": "cloud service", "type": '
#  '"generic", "component": "drdr_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "41.6139 '
#  '-72.7725", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "acuat_com", "description": "cloud service", "type": '
#  '"generic", "component": "acuat_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "45.5088 '
#  '-73.5878", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "databeen_ir", "description": "cloud service", '
#  '"type": "generic", "component": "databeen_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "camva_ir", "description": "cloud service", "type": '
#  '"generic", "component": "camva_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "51.5085 '
#  '-0.12574", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "khallagh_com", "description": "cloud service", '
#  '"type": "generic", "component": "khallagh_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "cloud_sigma_ir", "description": "cloud service", '
#  '"type": "generic", "component": "cloud_sigma_ir", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.5729 53.3971", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "haio_ir", "description": "cloud service", "type": '
#  '"generic", "component": "haio_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "50.6942 '
#  '3.17456", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "nrtc_ir", "description": "cloud service", "type": '
#  '"generic", "component": "nrtc_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "36.297 '
#  '59.6062", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parsnafe_com", "description": "cloud service", '
#  '"type": "generic", "component": "parsnafe_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "aryahamrah_com", "description": "cloud service", '
#  '"type": "generic", "component": "aryahamrah_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "jaygah_ir", "description": "cloud service", "type": '
#  '"generic", "component": "jaygah_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "38.9016 '
#  '-77.0508", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "sindad_com", "description": "cloud service", '
#  '"type": "generic", "component": "sindad_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "39.736 '
#  '-75.5465", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "avabarid_com", "description": "cloud service", '
#  '"type": "generic", "component": "avabarid_com", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "shatel_ir", "description": "cloud service", "type": '
#  '"generic", "component": "shatel_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "parsonline_com", "description": "cloud service", '
#  '"type": "generic", "component": "parsonline_com", "componentType": '
#  '"generic", "componentDesc": "cloud service", "publicAccess": true, '
#  '"location": "35.6944 51.4215", "timeZone": "CET"}]}')
# 200 b''
# ('{"sensors": [{"sensor": "hiweb_ir", "description": "cloud service", "type": '
#  '"generic", "component": "hiweb_ir", "componentType": "generic", '
#  '"componentDesc": "cloud service", "publicAccess": true, "location": "35.6944 '
#  '51.4215", "timeZone": "CET"}]}')
# 200 b''
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5d3c78aea832> in <module>()
#       7
#       8 for index, value in services.iterrows():
# ----> 9     address = getcountry(value["Address"])
#      10
#      11     data = {"sensors":[
#
# <ipython-input-4-d83b0ae90ac0> in getcountry(ip)
#       5 def getcountry(ip):
#       6     KEY = "e52ea3af34144855795d5e70b61ed107064383152ee97feed21d46a1d646180e"
# ----> 7     url = "http://api.ipinfodb.com/v3/ip-city/?key="+KEY+"&ip="+ip
#       8 #     url = "http://api.ipinfodb.com/v3/ip-country/?key="+KEY+"&ip="+ip
#       9     country_result = requests.get(url)
#
# TypeError: must be str, not float

# %%
import requests
import json
import pprint as pp

headers2 = {'IDENTITY_KEY': '46bf4060d758ba03488ca76947d317575f6872732e398c9db72707e25c7e0756'}


response = requests.get("http://myos.ir:8081/catalog/servers/", headers=headers2)
print(response.status_code)

data_json = json.loads(response.text)
lats = []
longs = []
for i in data_json['providers'][0]['sensors']:
    a = i['location'].split(' ')
    lats.append(float(a[0]))
    longs.append(float(a[1]))
len(lats)
# Out:
# 200
# 215

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.basemap import Basemap

m = Basemap(resolution='c',
            projection='kav7',
            lat_0=0., # Center around
            lon_0=0.) # lat 0, lon 0

n_graticules = 18
parallels = np.arange(-80., 90, n_graticules)
meridians = np.arange(0., 360., n_graticules)
lw = 1
dashes = [5,7] # 5 dots, 7 spaces... repeat
graticules_color = 'grey'

# %%
fig1 = plt.figure(figsize=(16,20))
fig1.patch.set_facecolor('#e6e8ec')
ax = fig1.add_axes([0.1,0.1,0.8,0.8])

m.drawmapboundary(color='white', 
                  linewidth=0.0, 
                  fill_color='white')
m.drawparallels(parallels, 
                linewidth=lw, 
                dashes=dashes, 
                color=graticules_color)
m.drawmeridians(meridians, 
                linewidth=lw, 
                dashes=dashes, 
                color=graticules_color)
m.drawcoastlines(linewidth=0)
m.fillcontinents('black', 
                 lake_color='white')
m.drawcountries(linewidth=1, 
                linestyle='solid', 
                color='white', 
                zorder=30)

title = plt.title('World map (Kavrayskiy 7)', 
                  fontsize=20) 
title.set_y(1.03) # Move the title a bit for niceness
# Out:
# /root/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %%
# http://maxberggren.se/2015/08/04/basemap/

# m.readshapefile('shapefiles/ne_110m_populated_places/ne_110m_populated_places', 
#                 name='populated_places', 
#                 drawbounds=False, 
#                 color='none')

fig1 = plt.figure(figsize=(16,20))
fig1.patch.set_facecolor('#e6e8ec')
ax = fig1.add_axes([0.1,0.1,0.8,0.8])

m.drawmapboundary(color='white', 
                  linewidth=0.0, 
                  fill_color='white')
m.drawparallels(parallels, 
                linewidth=lw, 
                dashes=dashes, 
                color=graticules_color)
m.drawmeridians(meridians, 
                linewidth=lw, 
                dashes=dashes, 
                color=graticules_color)
m.drawcoastlines(linewidth=0)
m.fillcontinents('black', 
                 lake_color='white')
m.drawcountries(linewidth=1, 
                linestyle='solid', 
                color='white', 
                zorder=30)

title = plt.title('World map (Kavrayskiy 7)', 
                  fontsize=20) 
title.set_y(1.03) 

# Move the title a bit for niceness
# populations = [r['POP2000'] for r in m.populated_places_info]
# lats = [r['LATITUDE'] for r in m.populated_places_info]
# lons = [r['LONGITUDE'] for r in m.populated_places_info]

x1, y1 = m(longs,lats) 
# Convert coords to projected place in figure
m.scatter(x1, y1, 
          s=np.array([50 for i in range(len(lats))])*5, 
          marker="o", 
          color='#32caf6',
          zorder=10, 
          alpha=0.8)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /root/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3222: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /root/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3231: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
